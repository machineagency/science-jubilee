# %% [markdown]
# # Birdseye Camera Calibration

# %%
import numpy as np
from science_jubilee.Machine import Machine
from science_jubilee.peripherals.BirdseyeCamera import BirdseyeCamera
from science_jubilee.tools.Syringe import Syringe

machine = Machine(address="192.168.1.2")
cam = BirdseyeCamera.from_config("BirdseyeCamera_config.json")
cam.attach(machine)
# Out:
# /Users/blairsubbaraman/research/pose26/science-jubilee/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 0
# response in connect:  [True, True, True, True]

# %% [markdown]
# The first thing you do is to home the machine, if you need to! Make sure the build plate is clear.

# %%
machine.home_all()

# %% [markdown]
# Homing could take a minute. Now, define and load tool(s).

# %%
# Change your tool numbers to match your machine!
syringe = Syringe(index = 2, name = "syringe", config = "10cc_syringe_liquidhandling")
machine.load_tool(syringe)

# %%
machine.pickup_tool(syringe)

# %%
# intrinsic calibration--load in
lens = np.load("../../../lens_calibration.npz")
cam.load_lens_calibration(lens["camera_matrix"], lens["dist_coeffs"])

# %%
# tape charuco board on bed if not done, and confirm they are visible
frame = cam.get_frame()
corners, ids, _ = cam.detect_aruco(frame)
print("Detected marker IDs:", ids.flatten() if ids is not None else "none")

annotated = cam.draw_detected_markers(frame, corners, ids)
cam.show_frame(annotated)
# Out:
# 2026-04-08 13:52:10.063 Python[72504:5514868] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# Detected marker IDs: [ 1  0  2  5  4  3  6  7  9  8 10 12 13 11 14 15 16 18 17 19 20 22 21 23
#  24 25 26]

# %%
# Jog tip to dot A (left dot, one square in from A-side)
# and save this position

pos = machine.get_position()
z_carriage = float(pos["Z"])
active_idx = machine.active_tool_index
if active_idx != -1 and active_idx in machine.tools:
    tool_offset = machine.tools[active_idx]["tool"].tool_offset
    Z_BED = z_carriage + abs(tool_offset) if tool_offset is not None else z_carriage
else:
    Z_BED = z_carriage
print(f"Z_BED = {Z_BED:.2f} mm")

corner_a = cam.collect_calibration_point(0)[1]
corner_a = (242.39, 90.51, 37.7) # hardcoded for convenience on youtubilee
corner_a = (241.0, 90.0, Z_BED) # hardcoded for convenience on cher
corner_a
# Out:
# Z_BED = 1.00 mm
# Marker 0 → machine position (65.000, -44.000, 1.000)
# (241.0, 90.0, 1.0)

# %%
# Jog tip to dot B (right dot, one square in from B-side), then run
corner_b = cam.collect_calibration_point(0)[1]
corner_b = (51.39, 92.51, 37.7) # hardcoded for convenience on youtubilee
corner_b = (53.0, 92.0, Z_BED) # hardcoded for convenience on cher
corner_b
# Out:
# Marker 0 → machine position (65.000, -44.000, 1.000)
# (53.0, 92.0, 1.0)

# %%
# Clear the tool so that your camera can see the whole charuco board

# %%
# Run calibration WITH PHYSICAL INPUT
# Make sure square_mm matches printed dimensions

# if the y axis is facing the wrong way after this, try
# flipping the y_sign between 1/-1 and try again
square_size_mm = 27 # update if needed
rvec, tvec = cam.calibrate_3d_charuco(
    boards=[(corner_a, corner_b)], y_sign=-1,
    board_cols=9, board_rows=6, square_mm=square_size_mm,
    save_path="camera_calibration-cher.npz",
    pixel_axes=([0, -1, 0], [-1, 0, 0]),  # px+ → machine -Y, py+ → machine -X
)
# Out:
#   Board 1: 40 corners
# ChArUco 3D calibration: 40/40 within 2px, RMS 0.92 px  (camera Z=-383.3 mm)
# Calibration saved to camera_calibration-cher.npz

# %%
def calibrate_z_stack(
    cam,
    machine,
    corner_a,
    corner_b,
    z_end=200,
    dz=5,
    board_cols=9,
    board_rows=6,
    square_mm=27,
    save_path="camera_calibration-cher.npz",
    y_sign=-1,
    pixel_axes=([0, -1, 0], [-1, 0, 0]),
):
    a_xy = corner_a[:2]
    b_xy = corner_b[:2]

    pos = machine.get_position()
    z_start = float(pos["Z"])
    z_values = np.arange(z_start, z_end + dz, dz)

    succeeded, failed = [], []
    for z in z_values:
        machine.move_to(z=z)
        a = (*a_xy, z)
        b = (*b_xy, z)
        print(f"\n--- Calibrating at Z={z:.1f} ---")
        try:
            cam.calibrate_3d_charuco(
                boards=[(a, b)],
                board_cols=board_cols,
                board_rows=board_rows,
                square_mm=square_mm,
                save_path=save_path,
                y_sign=y_sign,
                pixel_axes=pixel_axes,
            )
            succeeded.append(z)
        except Exception as e:
            print(f"  SKIPPED Z={z:.1f}: {e}")
            failed.append(z)

    print(f"\nZ-stack complete: {len(succeeded)} succeeded, {len(failed)} failed")
    print(f"Succeeded Z: {[round(z, 1) for z in succeeded]}")
    if failed:
        print(f"Failed Z:    {[round(z, 1) for z in failed]}")

# %%
## DEBUG
# Check if the calibration is reasonable
# Overlay machine positions on top of an image
# %matplotlib widget
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import numpy as np

# ── Config ───────────────────────────────────────────────────────────────────
Z_BED    = corner_a[2]   # Z of the bed surface used during calibration
X_RANGE  = (0, 320)      # machine X bounds to draw (mm)
Y_RANGE  = (0, 220)      # machine Y bounds to draw (mm)
SPACING  = 20            # grid spacing (mm)

# ── Capture ──────────────────────────────────────────────────────────────────
frame = cam.get_frame()

fig, ax = plt.subplots(figsize=(4, 4))
ax.imshow(frame)
ax.axis('off')

xs = np.arange(X_RANGE[0], X_RANGE[1] + 1, SPACING)
ys = np.arange(Y_RANGE[0], Y_RANGE[1] + 1, SPACING)

outline = [pe.Stroke(linewidth=2, foreground='black'), pe.Normal()]

# Vertical lines (constant X)
for x in xs:
    pts = [cam.machine_to_pixel(x, y, Z_BED) for y in ys]
    px_x = [p[0] for p in pts]
    px_y = [p[1] for p in pts]
    ax.plot(px_x, px_y, '-', color='cyan', linewidth=0.8, alpha=0.7)

# Horizontal lines (constant Y)
for y in ys:
    pts = [cam.machine_to_pixel(x, y, Z_BED) for x in xs]
    px_x = [p[0] for p in pts]
    px_y = [p[1] for p in pts]
    ax.plot(px_x, px_y, '-', color='cyan', linewidth=0.8, alpha=0.7)

# Labels at every other grid intersection
for x in xs[::2]:
    for y in ys[::2]:
        px, py = cam.machine_to_pixel(x, y, Z_BED)
        ax.text(px, py, f"{x:.0f},{y:.0f}",
                fontsize=5, color='yellow', ha='center', va='center',
                path_effects=outline)

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
calibrate_z_stack(cam, machine, corner_a, corner_b)
# Out:
# --- Calibrating at Z=1.0 ---
#   Board 1: 40 corners
# ChArUco 3D calibration: 39/40 within 2px, RMS 0.92 px  (camera Z=-383.6 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=6.0 ---
#   Board 1: 40 corners
# ChArUco 3D calibration: 38/40 within 2px, RMS 2.20 px  (camera Z=-382.9 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=11.0 ---
#   Board 1: 40 corners
# ChArUco 3D calibration: 40/40 within 2px, RMS 0.93 px  (camera Z=-383.7 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=16.0 ---
#   Board 1: 40 corners
# ChArUco 3D calibration: 38/40 within 2px, RMS 2.04 px  (camera Z=-383.1 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=21.0 ---
#   Board 1: 36 corners
# ChArUco 3D calibration: 34/36 within 2px, RMS 2.28 px  (camera Z=-383.6 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=26.0 ---
#   Board 1: 40 corners
# ChArUco 3D calibration: 36/40 within 2px, RMS 1.95 px  (camera Z=-383.2 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=31.0 ---
#   Board 1: 40 corners
# ChArUco 3D calibration: 37/40 within 2px, RMS 1.78 px  (camera Z=-384.9 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=36.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 37/38 within 2px, RMS 0.95 px  (camera Z=456.2 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=41.0 ---
#   Board 1: 36 corners
# ChArUco 3D calibration: 33/36 within 2px, RMS 1.68 px  (camera Z=467.0 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=46.0 ---
#   Board 1: 40 corners
# ChArUco 3D calibration: 38/40 within 2px, RMS 2.51 px  (camera Z=-384.4 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=51.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 35/38 within 2px, RMS 1.57 px  (camera Z=487.1 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=56.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 36/38 within 2px, RMS 1.64 px  (camera Z=497.2 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=61.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 36/38 within 2px, RMS 2.53 px  (camera Z=-384.5 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=66.0 ---
#   Board 1: 36 corners
# ChArUco 3D calibration: 30/36 within 2px, RMS 2.18 px  (camera Z=-386.1 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=71.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 38/38 within 2px, RMS 0.82 px  (camera Z=-384.9 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=76.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 37/38 within 2px, RMS 1.55 px  (camera Z=537.5 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=81.0 ---
#   Board 1: 40 corners
# ChArUco 3D calibration: 38/40 within 2px, RMS 1.53 px  (camera Z=-385.7 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=86.0 ---
#   Board 1: 30 corners
# ChArUco 3D calibration: 30/30 within 2px, RMS 0.85 px  (camera Z=556.8 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=91.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 37/38 within 2px, RMS 1.43 px  (camera Z=567.6 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=96.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 32/38 within 2px, RMS 3.49 px  (camera Z=579.0 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=101.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 35/38 within 2px, RMS 1.57 px  (camera Z=587.8 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=106.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 37/38 within 2px, RMS 1.46 px  (camera Z=598.2 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=111.0 ---
#   Board 1: 33 corners
# ChArUco 3D calibration: 32/33 within 2px, RMS 1.57 px  (camera Z=608.1 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=116.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 36/38 within 2px, RMS 1.44 px  (camera Z=618.3 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=121.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 36/38 within 2px, RMS 1.48 px  (camera Z=628.2 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=126.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 37/38 within 2px, RMS 1.41 px  (camera Z=638.3 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=131.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 37/38 within 2px, RMS 0.81 px  (camera Z=647.1 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=136.0 ---
#   Board 1: 36 corners
# ChArUco 3D calibration: 35/36 within 2px, RMS 0.86 px  (camera Z=657.5 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=141.0 ---
#   Board 1: 36 corners
# ChArUco 3D calibration: 34/36 within 2px, RMS 0.98 px  (camera Z=667.8 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=146.0 ---
#   Board 1: 38 corners
# ChArUco 3D calibration: 35/38 within 2px, RMS 1.42 px  (camera Z=679.3 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=151.0 ---
#   Board 1: 32 corners
# ChArUco 3D calibration: 4/32 within 2px, RMS 11.83 px  (camera Z=724.0 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=156.0 ---
#   Board 1: 35 corners
# ChArUco 3D calibration: 35/35 within 2px, RMS 0.80 px  (camera Z=698.0 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=161.0 ---
#   Board 1: 37 corners
# ChArUco 3D calibration: 0/37 within 2px, RMS 4.25 px  (camera Z=713.5 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=166.0 ---
#   Board 1: 34 corners
# ChArUco 3D calibration: 3/34 within 2px, RMS 11.08 px  (camera Z=753.5 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=171.0 ---
#   Board 1: 33 corners
# ChArUco 3D calibration: 32/33 within 2px, RMS 0.97 px  (camera Z=729.0 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=176.0 ---
#   Board 1: 32 corners
# ChArUco 3D calibration: 2/32 within 2px, RMS 10.72 px  (camera Z=773.0 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=181.0 ---
#   Board 1: 37 corners
# ChArUco 3D calibration: 2/37 within 2px, RMS 11.43 px  (camera Z=778.6 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=186.0 ---
#   Board 1: 34 corners
# ChArUco 3D calibration: 3/34 within 2px, RMS 10.42 px  (camera Z=791.7 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=191.0 ---
#   Board 1: 34 corners
# ChArUco 3D calibration: 3/34 within 2px, RMS 10.16 px  (camera Z=802.2 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=196.0 ---
#   Board 1: 26 corners
# ChArUco 3D calibration: 25/26 within 2px, RMS 0.91 px  (camera Z=779.7 mm)
# Calibration saved to camera_calibration-cher.npz
#
# --- Calibrating at Z=201.0 ---
#   Board 1: 35 corners
# ChArUco 3D calibration: 34/35 within 2px, RMS 1.05 px  (camera Z=788.7 mm)
# Calibration saved to camera_calibration-cher.npz
#
# Z-stack complete: 41 succeeded, 0 failed
# Succeeded Z: [np.float64(1.0), np.float64(6.0), np.float64(11.0), np.float64(16.0), np.float64(21.0), np.float64(26.0), np.float64(31.0), np.float64(36.0), np.float64(41.0), np.float64(46.0), np.float64(51.0), np.float64(56.0), np.float64(61.0), np.float64(66.0), np.float64(71.0), np.float64(76.0), np.float64(81.0), np.float64(86.0), np.float64(91.0), np.float64(96.0), np.float64(101.0), np.float64(106.0), np.float64(111.0), np.float64(116.0), np.float64(121.0), np.float64(126.0), np.float64(131.0), np.float64(136.0), np.float64(141.0), np.float64(146.0), np.float64(151.0), np.float64(156.0), np.float64(161.0), np.float64(166.0), np.float64(171.0), np.float64(176.0), np.float64(181.0), np.float64(186.0), np.float64(191.0), np.float64(196.0), np.float64(201.0)]

# %%
# Can inspect more here
import cv2
import numpy as np

frame = cam.get_frame()
gray = cv2.cvtColor(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR), cv2.COLOR_BGR2GRAY)

aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_100)
n_markers = (9 * 6 + 1) // 2
marker_ids = np.arange(0, n_markers, dtype=np.int32)
board = cv2.aruco.CharucoBoard((9, 6), 27, 20.25, aruco_dict, marker_ids)
detector = cv2.aruco.CharucoDetector(board)
corners, ids, _, _ = detector.detectBoard(gray)

if ids is None:
    print("No corners detected")
else:
    n_cx = 8
    a = np.array(corner_a[:2])
    b = np.array(corner_b[:2])
    x_unit = (b - a) / np.linalg.norm(b - a)
    y_unit = cam._board_y_unit  # stored during calibration

    print(f"{'ID':>4}  {'Detected px':>20}  {'Projected px':>20}  {'Error px':>10}")
    errors = []
    for k, cid in enumerate(ids.flatten()):
        col = int(cid) % n_cx
        row = int(cid) // n_cx
        mx = a[0] + col * 27 * x_unit[0] + row * 27 * y_unit[0]
        my = a[1] + col * 27 * x_unit[1] + row * 27 * y_unit[1]
        mz = corner_a[2]
        proj_px, proj_py = cam.machine_to_pixel(mx, my, mz)
        det = corners[k][0]
        err = np.sqrt((det[0] - proj_px)**2 + (det[1] - proj_py)**2)
        errors.append(err)
        print(f"{int(cid):>4}  ({det[0]:8.1f},{det[1]:8.1f})  ({proj_px:8.1f},{proj_py:8.1f})  {err:>10.2f}")
    print(f"\nMean error: {np.mean(errors):.2f} px   Max: {np.max(errors):.2f} px")

# %%
# 8. In future sessions — just load if the camera hasn't moved
# no need to redo calibration
lens = np.load("../../../lens_calibration.npz")
cam.load_lens_calibration(lens["camera_matrix"], lens["dist_coeffs"])
cam.load_calibration("camera_calibration-cher.npz")

# %%
z = Z_BED
cx = cam._camera_matrix[0, 2]
cy = cam._camera_matrix[1, 2]

m0 = cam.pixel_to_machine(cx, cy, z=z)
mr = cam.pixel_to_machine(cx + 100, cy, z=z)  # 100px right
md = cam.pixel_to_machine(cx, cy + 100, z=z)  # 100px down

print(f"Moving +100px in X (right):  ΔmachineX={mr[0]-m0[0]:+.1f}  ΔmachineY={mr[1]-m0[1]:+.1f}")
print(f"Moving +100px in Y (down):   ΔmachineX={md[0]-m0[0]:+.1f}  ΔmachineY={md[1]-m0[1]:+.1f}")
print()
print(f"Expected by you:")
print(f"  +100px right  → ΔmachineY < 0, ΔmachineX ≈ 0")
print(f"  +100px down   → ΔmachineX < 0, ΔmachineY ≈ 0")

# %%
cam.flip_y_axis()

mr2 = cam.pixel_to_machine(cx + 100, cy, z=z)
md2 = cam.pixel_to_machine(cx, cy + 100, z=z)

print(f"After flip — +100px right:  ΔmachineX={mr2[0]-m0[0]:+.1f}  ΔmachineY={mr2[1]-m0[1]:+.1f}")
print(f"After flip — +100px down:   ΔmachineX={md2[0]-m0[0]:+.1f}  ΔmachineY={md2[1]-m0[1]:+.1f}")

# %%
import cv2
import numpy as np

frame = cam.get_frame()
gray = cv2.cvtColor(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR), cv2.COLOR_BGR2GRAY)

aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_100)
n_markers = (9 * 6 + 1) // 2
marker_ids = np.arange(0, n_markers, dtype=np.int32)
board = cv2.aruco.CharucoBoard((9, 6), 27, 20.25, aruco_dict, marker_ids)
detector = cv2.aruco.CharucoDetector(board)
corners, ids, _, _ = detector.detectBoard(gray)

for target_id in [0, 1, 7, 8]:
    if ids is not None:
        mask = ids.flatten() == target_id
        if mask.any():
            k = np.where(mask)[0][0]
            px, py = corners[k][0]
            print(f"Corner ID {target_id}: pixel ({px:.1f}, {py:.1f})")

# %%
mx, my = cam.pixel_to_machine(2218, 954, z=corner_a[2])  # corner 8 pixel
print(f"Corner 8 predicted machine pos: ({mx:.1f}, {my:.1f})")

# %%
rvec_test, tvec_test = cam.calibrate_3d_charuco(
    boards=[(corner_a, corner_b)],
    board_cols=9, board_rows=6, square_mm=square_size_mm,
    y_sign=+1,  # temporary test
)

# %%
print("rvec:", rvec_test.flatten())

# %%
import numpy as np
data = np.load("camera_calibration-cher.npz")
print("Keys:", list(data.keys()))

if "z_cal_stack_z" in data:
    print("Z-stack entries:", data["z_cal_stack_z"])
else:
    print("NO z_cal_stack saved — stack was empty when file was written")
